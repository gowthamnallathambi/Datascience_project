# %% [markdown]
# <a href="https://colab.research.google.com/github/gowthamnallathambi/Datascience_project/blob/main/Morsum_Coding_Challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Morsum Coding Challenge - "Data Engineer"

# %% [markdown]
# # 1. Scripting
# ## In given ingredient_quantities.CSV file there are some null values in some columns which needs to fill in gaps using pandas, text parsing and arthmatic calculation in order find the total weight of the item.
#
# ![Screen Shot 2022-10-30 at 9.06.20 pm.png](data:image/png;base64,...)
#
# Fig.1: Given raw data in ingredient_quantities.CSV

# %% [markdown]
# ### To determine the "total weight" in the DataFrame, I populated in null values in some columns using the Python script shown below.

# %% [markdown]
# ![Screen Shot 2022-10-30 at 8.41.20 pm.png](data:image/png;base64,...)
#
# Fig2: Python script snippet

# %% [markdown]
# ### The script's output computes the "total_weight" utilizing additional columns and exports the DataFrame as a CSV file to the local machine.

# %% [markdown]
# ![Screen Shot 2022-10-30 at 9.19.48 pm.png](data:image/png;base64,...)
#
# Fig.3: Exported CSV file with calculated 'total_weight'

# %% [markdown]
# # 3. Pipeline code review
# ## Improved version of the following Airflow DAG, that addresses any performance, security or other best-practice issues.

# %% [markdown]
# ### I established a connection in the snippet below using Airflow's MySqlHook function. It enhances the security aspects by providing pipeline with encrypted connections.

# %% [markdown]
# ![Screen Shot 2022-10-30 at 10.48.16 pm.png](data:image/png;base64,...)
#
# Fig.3: Connection established using MySqlHook function
